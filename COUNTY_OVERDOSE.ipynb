# %%
#import dependencies 
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

# %%
#read in the county overdose data
overdose_df = pd.read_csv("NCHS_-_Drug_Poisoning_Mortality_by_County__United_States (1).csv")

# %%
#Overview of the data
overdose_df.head()
# Out:
#    FIPS  Year    State  ST  FIPS State              County  Population  \
# 0  1001  2015  Alabama  AL           1  Autauga County, AL     55347.0
# 1  1001  2002  Alabama  AL           1  Autauga County, AL     45909.0
# 2  1001  1999  Alabama  AL           1  Autauga County, AL     42963.0
# 3  1001  2007  Alabama  AL           1  Autauga County, AL     52405.0
# 4  1001  2010  Alabama  AL           1  Autauga County, AL     54660.0
#
#   Estimated Age-adjusted Death Rate, 16 Categories (in ranges)
# 0                                            10.1-12
# 1                                              4.1-6
# 2                                              2.1-4
# 3                                              6.1-8
# 4                                             8.1-10

# %%
#groupby county
overdose_County_df =overdose_df.groupby("County")
overdose_County_df.head()
# Out:
#         FIPS  Year    State  ST  FIPS State                 County  \
# 0       1001  2015  Alabama  AL           1     Autauga County, AL
# 1       1001  2002  Alabama  AL           1     Autauga County, AL
# 2       1001  1999  Alabama  AL           1     Autauga County, AL
# 3       1001  2007  Alabama  AL           1     Autauga County, AL
# 4       1001  2010  Alabama  AL           1     Autauga County, AL
# 17      1003  2009  Alabama  AL           1     Baldwin County, AL
# 18      1003  2013  Alabama  AL           1     Baldwin County, AL
# 19      1003  2003  Alabama  AL           1     Baldwin County, AL
# 20      1003  2005  Alabama  AL           1     Baldwin County, AL
# 21      1003  2002  Alabama  AL           1     Baldwin County, AL
# 34      1005  2001  Alabama  AL           1     Barbour County, AL
# 35      1005  2008  Alabama  AL           1     Barbour County, AL
# 36      1005  1999  Alabama  AL           1     Barbour County, AL
# ...

# %%
county_indexed = overdose_df.set_index(['Year','County','ST','Population']).sort_index()
county_indexed.head()
# Out:
#                                           FIPS           State  FIPS State  \
# Year County               ST Population
# 1999 Abbeville County, SC SC 25921.0     45001  South Carolina          45
#      Acadia Parish, LA    LA 58762.0     22001       Louisiana          22
#      Accomack County, VA  VA 37614.0     51001        Virginia          51
#      Ada County, ID       ID 294292.0    16001           Idaho          16
#      Adair County, IA     IA 8298.0      19001            Iowa          19
#
#                                         Estimated Age-adjusted Death Rate, 16 Categories (in ranges)
# Year County               ST Population
# 1999 Abbeville County, SC SC 25921.0                                                   0-2
#      Acadia Parish, LA    LA 58762.0                                                 6.1-8
#      Accomack County, VA  VA 37614.0                                                 4.1-6
# ...

# %%
#check out the columns 
county_indexed.columns
# Out:
# Index(['FIPS', 'State', 'FIPS State',
#        'Estimated Age-adjusted Death Rate, 16 Categories (in ranges)'],
#       dtype='object')

# %%
#drop uneeded columns

cleaned_county_df = county_indexed.drop(['FIPS State', 'Estimated Age-adjusted Death Rate','16 Categories (in ranges)', axis=1,inplace=True)
# Out:
#   File "<ipython-input-62-a5f94d302a76>", line 1
#     cleaned_county_df = county_indexed.drop(['FIPS State', 'Estimated Age-adjusted Death Rate','16 Categories (in ranges)', axis=1,inplace=True)
#                                                                                                                                 ^
# SyntaxError: invalid syntax
