# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census

# Census API Key
from config import api_key
c = Census(api_key, year=2013)

# %%
eco_data_2013 = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E", "B23025_003E","B23025_005E",
                          "B17001_002E"), {'for': 'state:*'})


eco_2013 = pd.DataFrame(eco_data_2013)


eco_2013 = eco_2013.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "B23025_003E": "Employable Count",
                                      "B23025_005E": "Unemployment Count",
                                      "NAME": "Name", "state": "State"})


eco_2013["Poverty Rate"] = 100 * \
    eco_2013["Poverty Count"].astype(
        int) / eco_2013["Population"].astype(int)

eco_2013["Unemployment Rate"] = 100 * \
    eco_2013["Unemployment Count"].astype(
        int) / eco_2013["Employable Count"].astype(int)


eco_2013 = eco_2013[["State","Name","Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count", "Poverty Rate","Employable Count","Unemployment Count", "Unemployment Rate"]]


print(len(eco_2013))
eco_2013.head()
# Out:
# 52
#   State        Name  Population  Median Age  Household Income  \
# 0    01     Alabama   4799277.0        38.1           43253.0
# 1    02      Alaska    720316.0        33.6           70760.0
# 2    04     Arizona   6479703.0        36.3           49774.0
# 3    05    Arkansas   2933369.0        37.5           40768.0
# 4    06  California  37659181.0        35.4           61094.0
#
#    Per Capita Income  Poverty Count  Poverty Rate  Employable Count  \
# 0            23680.0       870631.0     18.140878         2244093.0
# 1            32651.0        69514.0      9.650487          376305.0
# 2            25358.0      1131901.0     17.468409         3038226.0
# 3            22170.0       547328.0     18.658682         1366667.0
# 4            29527.0      5885417.0     15.628107        18804519.0
#
#    Unemployment Count  Unemployment Rate
# 0            241930.0          10.780748
# 1             32939.0           8.753272
# 2            316360.0          10.412655
# ...

# %%
eco_2013.to_csv("State_2013/census_economic_2013.csv", encoding="utf-8", index=False)

# %%
edu_data_2013= c.acs5.get(("NAME","B01003_001E", "B15003_002E",
                               "B15003_017E",
                               "B15003_018E",
                               "B15003_021E",
                               "B15003_022E",
                               "B15003_023E",
                               "B15003_024E",
                           "B15003_025E"), {'for': 'state:*'})

edu_2013=pd.DataFrame(edu_data_2013)

edu_2013=edu_2013.rename(columns={"B01003_001E": "Population","B15003_002E": "None",
                               "B15003_017E": "High School Degree",
                               "B15003_018E": "GED",
                               "B15003_021E": "Associate Degree",
                               "B15003_022E": "Bachelor Degree",
                               "B15003_023E":"Masters Degree",
                               "B15003_024E": "Professional Degree",
                           "B15003_025E":"Doctorate Degree", "NAME": "Name","state": "State"})

edu_2013= edu_2013[["State", "Name","Population","None","High School Degree","GED","Associate Degree","Bachelor Degree","Masters Degree","Professional Degree","Doctorate Degree"]]

edu_2013["High School and above"]= (edu_2013["High School Degree"]+edu_2013["GED"]+edu_2013["Associate Degree"]+edu_2013["Bachelor Degree"]+edu_2013["Masters Degree"]+edu_2013["Professional Degree"]+edu_2013["Doctorate Degree"])


edu_2013.head()
# Out:
#   State        Name  Population      None  High School Degree       GED  \
# 0    01     Alabama   4799277.0   40711.0            818315.0  173415.0
# 1    02      Alaska    720316.0    2796.0            101267.0   22792.0
# 2    04     Arizona   6479703.0   52419.0            863210.0  168804.0
# 3    05    Arkansas   2933369.0   22954.0            561542.0  117797.0
# 4    06  California  37659181.0  598141.0           4525094.0  540940.0
#
#    Associate Degree  Bachelor Degree  Masters Degree  Professional Degree  \
# 0          236473.0         458393.0        187852.0              45646.0
# 1           36351.0          80447.0         31988.0               7431.0
# 2          350503.0         716734.0        296979.0              69819.0
# 3          119038.0         257157.0         93456.0              23201.0
# 4         1895918.0        4753446.0       1821325.0             565907.0
#
#    Doctorate Degree  High School and above
# 0           30801.0              1950895.0
# ...

# %%
edu_2013.to_csv("State_2013/census_education_2013.csv",encoding="utf-8",index=False)

# %%
from config import api_key
c = Census(api_key, year=2014)

# %%
eco_data_2014 = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E", "B23025_003E","B23025_005E",
                          "B17001_002E"), {'for': 'state:*'})


eco_2014 = pd.DataFrame(eco_data_2014)


eco_2014 = eco_2014.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "B23025_003E": "Employable Count",
                                      "B23025_005E": "Unemployment Count",
                                      "NAME": "Name", "state": "State"})


eco_2014["Poverty Rate"] = 100 * \
    eco_2014["Poverty Count"].astype(
        int) / eco_2014["Population"].astype(int)

eco_2014["Unemployment Rate"] = 100 * \
    eco_2014["Unemployment Count"].astype(
        int) / eco_2014["Employable Count"].astype(int)


eco_2014 = eco_2014[["State","Name","Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count", "Poverty Rate","Employable Count","Unemployment Count", "Unemployment Rate"]]


print(len(eco_2014))
eco_2014.head()
# Out:
# 52
#   State        Name  Population  Median Age  Household Income  \
# 0    01     Alabama   4817678.0        38.2           43511.0
# 1    02      Alaska    728300.0        33.4           71829.0
# 2    04     Arizona   6561516.0        36.5           49928.0
# 3    05    Arkansas   2947036.0        37.6           41264.0
# 4    06  California  38066920.0        35.6           61489.0
#
#    Per Capita Income  Poverty Count  Poverty Rate  Employable Count  \
# 0            23936.0       889710.0     18.467610         2239169.0
# 1            33129.0        71866.0      9.867637          380080.0
# 2            25537.0      1169309.0     17.820714         3059049.0
# 3            22595.0       549303.0     18.639168         1366807.0
# 4            29906.0      6115244.0     16.064457        18975006.0
#
#    Unemployment Count  Unemployment Rate
# 0            228716.0          10.214325
# 1             32097.0           8.444801
# 2            304067.0           9.939919
# ...

# %%
eco_2014.to_csv("State_2014/census_economic_2014.csv", encoding="utf-8", index=False)

# %%
edu_data_2014= c.acs5.get(("NAME","B01003_001E", "B15003_002E",
                               "B15003_017E",
                               "B15003_018E",
                               "B15003_021E",
                               "B15003_022E",
                               "B15003_023E",
                               "B15003_024E",
                           "B15003_025E"), {'for': 'state:*'})

edu_2014=pd.DataFrame(edu_data_2014)

edu_2014=edu_2014.rename(columns={"B01003_001E": "Population","B15003_002E": "None",
                               "B15003_017E": "High School Degree",
                               "B15003_018E": "GED",
                               "B15003_021E": "Associate Degree",
                               "B15003_022E": "Bachelor Degree",
                               "B15003_023E":"Masters Degree",
                               "B15003_024E": "Professional Degree",
                           "B15003_025E":"Doctorate Degree", "NAME": "Name","state": "State"})

edu_2014= edu_2014[["State", "Name","Population","None","High School Degree","GED","Associate Degree","Bachelor Degree","Masters Degree","Professional Degree","Doctorate Degree"]]

edu_2014["High School and above"]= (edu_2014["High School Degree"]+edu_2014["GED"]+edu_2014["Associate Degree"]+edu_2014["Bachelor Degree"]+edu_2014["Masters Degree"]+edu_2014["Professional Degree"]+edu_2014["Doctorate Degree"])

edu_2014.head()
# Out:
#   State        Name  Population      None  High School Degree       GED  \
# 0    01     Alabama   4817678.0   41671.0            824979.0  174782.0
# 1    02      Alaska    728300.0    2924.0            103345.0   23266.0
# 2    04     Arizona   6561516.0   55703.0            877163.0  172916.0
# 3    05    Arkansas   2947036.0   22572.0            564546.0  117905.0
# 4    06  California  38066920.0  624808.0           4597854.0  555403.0
#
#    Associate Degree  Bachelor Degree  Masters Degree  Professional Degree  \
# 0          243873.0         465268.0        196935.0              47795.0
# 1           37684.0          82261.0         32681.0               7370.0
# 2          360743.0         733845.0        306410.0              71569.0
# 3          121464.0         263299.0         98442.0              24187.0
# 4         1934950.0        4870524.0       1889640.0             575093.0
#
#    Doctorate Degree  High School and above
# 0           31815.0              1985447.0
# ...

# %%
edu_2014.to_csv("State_2014/census_education_2014.csv",encoding="utf-8",index=False)

# %%
from config import api_key
c = Census(api_key, year=2015)

# %%
eco_data_2015 = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E", "B23025_003E","B23025_005E",
                          "B17001_002E"), {'for': 'state:*'})


eco_2015 = pd.DataFrame(eco_data_2015)


eco_2015 = eco_2015.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "B23025_003E": "Employable Count",
                                      "B23025_005E": "Unemployment Count",
                                      "NAME": "Name", "state": "State"})


eco_2015["Poverty Rate"] = 100 * \
    eco_2015["Poverty Count"].astype(
        int) / eco_2015["Population"].astype(int)

eco_2015["Unemployment Rate"] = 100 * \
    eco_2015["Unemployment Count"].astype(
        int) / eco_2015["Employable Count"].astype(int)


eco_2015 = eco_2015[["State","Name","Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count", "Poverty Rate","Employable Count","Unemployment Count", "Unemployment Rate"]]


print(len(eco_2015))
eco_2015.head()
# Out:
# 52
#   State        Name  Population  Median Age  Household Income  \
# 0    02      Alaska    733375.0        33.4           72515.0
# 1    01     Alabama   4830620.0        38.4           43623.0
# 2    05    Arkansas   2958208.0        37.7           41371.0
# 3    04     Arizona   6641928.0        36.8           50255.0
# 4    06  California  38421464.0        35.8           61818.0
#
#    Per Capita Income  Poverty Count  Poverty Rate  Employable Count  \
# 0            33413.0        72957.0      9.948117          382393.0
# 1            24091.0       887260.0     18.367415         2229422.0
# 2            22798.0       553644.0     18.715520         1361024.0
# 3            25848.0      1180690.0     17.776314         3089118.0
# 4            30318.0      6135142.0     15.968007        19137441.0
#
#    Unemployment Count  Unemployment Rate
# 0             31285.0           8.181374
# 1            207097.0           9.289269
# 2            104943.0           7.710591
# ...

# %%
eco_2015.to_csv("State_2015/census_economic_2015.csv", encoding="utf-8", index=False)

# %%
edu_data_2015= c.acs5.get(("NAME","B01003_001E", "B15003_002E",
                               "B15003_017E",
                               "B15003_018E",
                               "B15003_021E",
                               "B15003_022E",
                               "B15003_023E",
                               "B15003_024E",
                           "B15003_025E"), {'for': 'state:*'})

edu_2015=pd.DataFrame(edu_data_2015)

edu_2015=edu_2015.rename(columns={"B01003_001E": "Population","B15003_002E": "None",
                               "B15003_017E": "High School Degree",
                               "B15003_018E": "GED",
                               "B15003_021E": "Associate Degree",
                               "B15003_022E": "Bachelor Degree",
                               "B15003_023E":"Masters Degree",
                               "B15003_024E": "Professional Degree",
                           "B15003_025E":"Doctorate Degree", "NAME": "Name","state": "State"})

edu_2015= edu_2015[["State", "Name","Population","None","High School Degree","GED","Associate Degree","Bachelor Degree","Masters Degree","Professional Degree","Doctorate Degree"]]

edu_2015["High School and above"]= (edu_2015["High School Degree"]+edu_2015["GED"]+edu_2015["Associate Degree"]+edu_2015["Bachelor Degree"]+edu_2015["Masters Degree"]+edu_2015["Professional Degree"]+edu_2015["Doctorate Degree"])

edu_2015.head()
# Out:
#   State        Name  Population      None  High School Degree       GED  \
# 0    02      Alaska    733375.0    2977.0            105527.0   23797.0
# 1    01     Alabama   4830620.0   41876.0            826272.0  179023.0
# 2    05    Arkansas   2958208.0   23014.0            564438.0  120839.0
# 3    04     Arizona   6641928.0   59117.0            887064.0  176701.0
# 4    06  California  38421464.0  652517.0           4661300.0  570524.0
#
#    Associate Degree  Bachelor Degree  Masters Degree  Professional Degree  \
# 0           37719.0          83201.0         33447.0               8271.0
# 1          251335.0         478812.0        201997.0              48509.0
# 2          123526.0         267741.0        103397.0              24613.0
# 3          370569.0         753425.0        321027.0              73284.0
# 4         1970322.0        5002596.0       1965005.0             583790.0
#
#    Doctorate Degree  High School and above
# 0            5002.0               296964.0
# ...

# %%
edu_2015.to_csv("State_2015/census_education_2015.csv",encoding="utf-8",index=False)

# %%
from config import api_key
c = Census(api_key, year=2016)

# %%
eco_data_2016 = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E", "B23025_003E","B23025_005E",
                          "B17001_002E"), {'for': 'state:*'})


eco_2016 = pd.DataFrame(eco_data_2016)


eco_2016 = eco_2016.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "B23025_003E": "Employable Count",
                                      "B23025_005E": "Unemployment Count",
                                      "NAME": "Name", "state": "State"})


eco_2016["Poverty Rate"] = 100 * \
    eco_2016["Poverty Count"].astype(
        int) / eco_2016["Population"].astype(int)

eco_2016["Unemployment Rate"] = 100 * \
    eco_2016["Unemployment Count"].astype(
        int) / eco_2016["Employable Count"].astype(int)


eco_2016 = eco_2016[["State","Name","Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count", "Poverty Rate","Employable Count","Unemployment Count", "Unemployment Rate"]]


print(len(eco_2016))
eco_2016.head()
# Out:
# 52
#   State        Name  Population  Median Age  Household Income  \
# 0    01     Alabama   4841164.0        38.6           44758.0
# 1    02      Alaska    736855.0        33.6           74444.0
# 2    04     Arizona   6728577.0        37.1           51340.0
# 3    05    Arkansas   2968472.0        37.7           42336.0
# 4    06  California  38654206.0        36.0           63783.0
#
#    Per Capita Income  Poverty Count  Poverty Rate  Employable Count  \
# 0            24736.0       868666.0     17.943329         2226504.0
# 1            34191.0        72826.0      9.883356          384093.0
# 2            26686.0      1165636.0     17.323663         3129344.0
# 3            23401.0       542431.0     18.273071         1359742.0
# 4            31458.0      6004257.0     15.533257        19260868.0
#
#    Unemployment Count  Unemployment Rate
# 0            184479.0           8.285590
# 1             30139.0           7.846798
# 2            249972.0           7.988000
# ...

# %%
eco_2016.to_csv("State_2016/census_economic_2016.csv", encoding="utf-8", index=False)

# %%
edu_data_2016= c.acs5.get(("NAME","B01003_001E", "B15003_002E",
                               "B15003_017E",
                               "B15003_018E",
                               "B15003_021E",
                               "B15003_022E",
                               "B15003_023E",
                               "B15003_024E",
                           "B15003_025E"), {'for': 'state:*'})

edu_2016=pd.DataFrame(edu_data_2016)

edu_2016=edu_2016.rename(columns={"B01003_001E": "Population","B15003_002E": "None",
                               "B15003_017E": "High School Degree",
                               "B15003_018E": "GED",
                               "B15003_021E": "Associate Degree",
                               "B15003_022E": "Bachelor Degree",
                               "B15003_023E":"Masters Degree",
                               "B15003_024E": "Professional Degree",
                           "B15003_025E":"Doctorate Degree", "NAME": "Name","state": "State"})

edu_2016= edu_2016[["State", "Name","Population","None","High School Degree","GED","Associate Degree","Bachelor Degree","Masters Degree","Professional Degree","Doctorate Degree"]]

edu_2016["High School and above"]= (edu_2016["High School Degree"]+edu_2016["GED"]+edu_2016["Associate Degree"]+edu_2016["Bachelor Degree"]+edu_2016["Masters Degree"]+edu_2016["Professional Degree"]+edu_2016["Doctorate Degree"])

edu_2016.head()
# Out:
#   State        Name  Population      None  High School Degree       GED  \
# 0    01     Alabama   4841164.0   42577.0            828205.0  181388.0
# 1    02      Alaska    736855.0    3020.0            106169.0   24342.0
# 2    04     Arizona   6728577.0   62538.0            898657.0  179701.0
# 3    05    Arkansas   2968472.0   23010.0            561132.0  122754.0
# 4    06  California  38654206.0  673089.0           4678279.0  582625.0
#
#    Associate Degree  Bachelor Degree  Masters Degree  Professional Degree  \
# 0          258502.0         492382.0        208839.0              49283.0
# 1           39133.0          86551.0         35423.0               8522.0
# 2          379207.0         777681.0        333226.0              76987.0
# 3          127004.0         273557.0        108055.0              24517.0
# 4         1995579.0        5136043.0       2045487.0             597874.0
#
#    Doctorate Degree  High School and above
# 0           32572.0              2051171.0
# ...

# %%
edu_2016.to_csv("State_2016/census_education_2016.csv",encoding="utf-8",index=False)

# %%
from config import api_key
c = Census(api_key, year=2012)

# %%
eco_data_2012 = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E", "B23025_003E","B23025_005E",
                          "B17001_002E"), {'for': 'state:*'})


eco_2012 = pd.DataFrame(eco_data_2012)


eco_2012 = eco_2012.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "B23025_003E": "Employable Count",
                                      "B23025_005E": "Unemployment Count",
                                      "NAME": "Name", "state": "State"})


eco_2012["Poverty Rate"] = 100 * \
    eco_2012["Poverty Count"].astype(
        int) / eco_2012["Population"].astype(int)

eco_2012["Unemployment Rate"] = 100 * \
    eco_2012["Unemployment Count"].astype(
        int) / eco_2012["Employable Count"].astype(int)


eco_2012 = eco_2012[["State","Name","Population", "Median Age", "Household Income",
                       "Per Capita Income", "Poverty Count", "Poverty Rate","Employable Count","Unemployment Count", "Unemployment Rate"]]


print(len(eco_2012))
eco_2012.head()
# Out:
# 52
#   State        Name  Population  Median Age  Household Income  \
# 0    01     Alabama   4777326.0        37.8           43160.0
# 1    02      Alaska    711139.0        33.8           69917.0
# 2    04     Arizona   6410979.0        36.0           50256.0
# 3    05    Arkansas   2916372.0        37.4           40531.0
# 4    06  California  37325068.0        35.2           61400.0
#
#    Per Capita Income  Poverty Count  Poverty Rate  Employable Count  \
# 0            23587.0       842292.0     17.631035         2248665.0
# 1            32537.0        66631.0      9.369617          372484.0
# 2            25571.0      1074986.0     16.767891         3029669.0
# 3            22007.0       530309.0     18.183860         1370423.0
# 4            29551.0      5590100.0     14.976798        18673806.0
#
#    Unemployment Count  Unemployment Rate
# 0            230778.0          10.262889
# 1             31369.0           8.421570
# 2            296132.0           9.774401
# ...

# %%
eco_2012.to_csv("State_2012/census_economic_2012.csv", encoding="utf-8", index=False)

# %%
edu_data_2012= c.acs5.get(("NAME","B01003_001E", "B15003_002E",
                               "B15003_017E",
                               "B15003_018E",
                               "B15003_021E",
                               "B15003_022E",
                               "B15003_023E",
                               "B15003_024E",
                           "B15003_025E"), {'for': 'state:*'})

edu_2012=pd.DataFrame(edu_data_2012)

edu_2012=edu_2012.rename(columns={"B01003_001E": "Population","B15003_002E": "None",
                               "B15003_017E": "High School Degree",
                               "B15003_018E": "GED",
                               "B15003_021E": "Associate Degree",
                               "B15003_022E": "Bachelor Degree",
                               "B15003_023E":"Masters Degree",
                               "B15003_024E": "Professional Degree",
                           "B15003_025E":"Doctorate Degree", "NAME": "Name","state": "State"})

edu_2012= edu_2012[["State", "Name","Population","None","High School Degree","GED","Associate Degree","Bachelor Degree","Masters Degree","Professional Degree","Doctorate Degree"]]

edu_2012["High School and above"]= (edu_2012["High School Degree"]+edu_2012["GED"]+edu_2012["Associate Degree"]+edu_2012["Bachelor Degree"]+edu_2012["Masters Degree"]+edu_2012["Professional Degree"]+edu_2012["Doctorate Degree"])

edu_2012.head()
# Out:
#   State        Name  Population      None  High School Degree       GED  \
# 0    01     Alabama   4777326.0   40659.0            818162.0  173244.0
# 1    02      Alaska    711139.0    2674.0             98765.0   22507.0
# 2    04     Arizona   6410979.0   51467.0            847998.0  164505.0
# 3    05    Arkansas   2916372.0   22509.0            559309.0  115433.0
# 4    06  California  37325068.0  575881.0           4461255.0  527304.0
#
#    Associate Degree  Bachelor Degree  Masters Degree  Professional Degree  \
# 0          227301.0         448117.0        182960.0              44662.0
# 1           35312.0          79441.0         30708.0               7497.0
# 2          339398.0         702007.0        288414.0              68944.0
# 3          116356.0         252579.0         89971.0              22997.0
# 4         1861509.0        4667570.0       1766387.0             558834.0
#
#    Doctorate Degree  High School and above
# 0           29262.0              1923708.0
# ...

# %%
edu_2012.to_csv("State_2012/census_education_2012.csv",encoding="utf-8",index=False)

# %%
#10 Highest Unemployment rate for States in 2013
top_unemployment_2013 = eco_2013.sort_values(["Unemployment Rate"], ascending=False)

top_unemployment_2013.reset_index(inplace=True)

top_unemployment_2013.head(20)
# Out:
#     index State                  Name  Population  Median Age  \
# 0      51    72           Puerto Rico   3682966.0        37.5
# 1      22    26              Michigan   9886095.0        39.1
# 2      28    32                Nevada   2730066.0        36.6
# 3       9    12               Florida  19091156.0        41.0
# 4       4    06            California  37659181.0        35.4
# 5      40    45        South Carolina   4679602.0        38.1
# 6      10    13               Georgia   9810417.0        35.6
# 7      37    41                Oregon   3868721.0        38.7
# 8      24    28           Mississippi   2976872.0        36.2
# 9      33    37        North Carolina   9651380.0        37.6
# 10      8    11  District of Columbia    619371.0        33.8
# 11      0    01               Alabama   4799277.0        38.1
# 12     13    17              Illinois  12848554.0        36.8
# 13      2    04               Arizona   6479703.0        36.3
# ...

# %%
#10 Highest Poverty rate for States in 2013
top_poverty_2013 = eco_2013.sort_values(["Poverty Rate"], ascending=False)

top_poverty_2013.reset_index(inplace=True)

top_poverty_2013.head(20)
# Out:
#     index State                  Name  Population  Median Age  \
# 0      51    72           Puerto Rico   3682966.0        37.5
# 1      24    28           Mississippi   2976872.0        36.2
# 2      31    35            New Mexico   2069706.0        36.7
# 3       3    05              Arkansas   2933369.0        37.5
# 4      18    22             Louisiana   4567968.0        36.0
# 5      17    21              Kentucky   4361333.0        38.2
# 6       0    01               Alabama   4799277.0        38.1
# 7      10    13               Georgia   9810417.0        35.6
# 8       8    11  District of Columbia    619371.0        33.8
# 9      40    45        South Carolina   4679602.0        38.1
# 10      2    04               Arizona   6479703.0        36.3
# 11     48    54         West Virginia   1853619.0        41.5
# 12     43    48                 Texas  25639373.0        33.8
# 13     42    47             Tennessee   6402387.0        38.2
# ...

# %%
#10 Highest Unemployment rate for States in 2014
top_unemployment_2014 = eco_2014.sort_values(["Unemployment Rate"], ascending=False)

top_unemployment_2014.reset_index(inplace=True)

top_unemployment_2014.head(20)
# Out:
#     index State                  Name  Population  Median Age  \
# 0      51    72           Puerto Rico   3638965.0        38.1
# 1      28    32                Nevada   2761584.0        36.9
# 2      22    26              Michigan   9889024.0        39.3
# 3       4    06            California  38066920.0        35.6
# 4       9    12               Florida  19361792.0        41.2
# 5      24    28           Mississippi   2984345.0        36.3
# 6      10    13               Georgia   9907756.0        35.8
# 7      40    45        South Carolina   4727273.0        38.3
# 8       8    11  District of Columbia    633736.0        33.7
# 9      33    37        North Carolina   9750405.0        37.8
# 10     37    41                Oregon   3900343.0        38.9
# 11      0    01               Alabama   4817678.0        38.2
# 12     13    17              Illinois  12868747.0        37.0
# 13      2    04               Arizona   6561516.0        36.5
# ...

# %%
#10 Highest Poverty rate for States in 2014
top_poverty_2014 = eco_2014.sort_values(["Poverty Rate"], ascending=False)

top_poverty_2014.reset_index(inplace=True)

top_poverty_2014.head(20)
# Out:
#     index State                  Name  Population  Median Age  \
# 0      51    72           Puerto Rico   3638965.0        38.1
# 1      24    28           Mississippi   2984345.0        36.3
# 2      31    35            New Mexico   2080085.0        36.8
# 3      18    22             Louisiana   4601049.0        36.0
# 4       3    05              Arkansas   2947036.0        37.6
# 5       0    01               Alabama   4817678.0        38.2
# 6      17    21              Kentucky   4383272.0        38.3
# 7      10    13               Georgia   9907756.0        35.8
# 8       2    04               Arizona   6561516.0        36.5
# 9      40    45        South Carolina   4727273.0        38.3
# 10     48    54         West Virginia   1853881.0        41.6
# 11     42    47             Tennessee   6451365.0        38.3
# 12      8    11  District of Columbia    633736.0        33.7
# 13     43    48                 Texas  26092033.0        33.9
# ...

# %%
#10 Highest Unemployment rate for States in 2015
top_unemployment_2015 = eco_2015.sort_values(["Unemployment Rate"], ascending=False)

top_unemployment_2015.reset_index(inplace=True)

top_unemployment_2015.head(20)
# Out:
#     index State                  Name  Population  Median Age  \
# 0      39    72           Puerto Rico   3583073.0        38.7
# 1      33    32                Nevada   2798636.0        37.2
# 2      25    28           Mississippi   2988081.0        36.5
# 3       4    06            California  38421464.0        35.8
# 4      22    26              Michigan   9900571.0        39.5
# 5       9    12               Florida  19645772.0        41.4
# 6      10    13               Georgia  10006693.0        35.9
# 7       7    11  District of Columbia    647484.0        33.7
# 8      41    45        South Carolina   4777576.0        38.6
# 9      27    37        North Carolina   9845333.0        38.0
# 10     37    41                Oregon   3939233.0        39.1
# 11      1    01               Alabama   4830620.0        38.4
# 12     32    35            New Mexico   2084117.0        37.0
# 13     14    17              Illinois  12873761.0        37.3
# ...

# %%
#10 Highest Poverty rate for States in 2015
top_poverty_2015 = eco_2015.sort_values(["Poverty Rate"], ascending=False)

top_poverty_2015.reset_index(inplace=True)

top_poverty_2015.head(20)
# Out:
#     index State                  Name  Population  Median Age  \
# 0      39    72           Puerto Rico   3583073.0        38.7
# 1      25    28           Mississippi   2988081.0        36.5
# 2      32    35            New Mexico   2084117.0        37.0
# 3      18    22             Louisiana   4625253.0        36.1
# 4       2    05              Arkansas   2958208.0        37.7
# 5       1    01               Alabama   4830620.0        38.4
# 6      17    21              Kentucky   4397353.0        38.5
# 7      10    13               Georgia  10006693.0        35.9
# 8       3    04               Arizona   6641928.0        36.8
# 9      50    54         West Virginia   1851420.0        41.8
# 10     41    45        South Carolina   4777576.0        38.6
# 11     43    47             Tennessee   6499615.0        38.4
# 12      7    11  District of Columbia    647484.0        33.7
# 13     27    37        North Carolina   9845333.0        38.0
# ...

# %%
#10 Highest Unemployment rate for States in 2016
top_unemployment_2016 = eco_2016.sort_values(["Unemployment Rate"], ascending=False)

top_unemployment_2016.reset_index(inplace=True)

top_unemployment_2016.head(20)
# Out:
#     index State                  Name  Population  Median Age  \
# 0      51    72           Puerto Rico   3529385.0        39.4
# 1      24    28           Mississippi   2989192.0        36.7
# 2      28    32                Nevada   2839172.0        37.5
# 3       4    06            California  38654206.0        36.0
# 4       8    11  District of Columbia    659009.0        33.8
# 5      10    13               Georgia  10099320.0        36.2
# 6      22    26              Michigan   9909600.0        39.5
# 7      31    35            New Mexico   2082669.0        37.2
# 8       9    12               Florida  19934451.0        41.6
# 9      40    45        South Carolina   4834605.0        38.8
# 10     33    37        North Carolina   9940828.0        38.3
# 11      0    01               Alabama   4841164.0        38.6
# 12     13    17              Illinois  12851684.0        37.4
# 13     37    41                Oregon   3982267.0        39.1
# ...

# %%
#10 Highest Poverty rate for States in 2016
top_poverty_2016 = eco_2016.sort_values(["Poverty Rate"], ascending=False)

top_poverty_2016.reset_index(inplace=True)

top_poverty_2016.head(20)
# Out:
#     index State                  Name  Population  Median Age  \
# 0      51    72           Puerto Rico   3529385.0        39.4
# 1      24    28           Mississippi   2989192.0        36.7
# 2      31    35            New Mexico   2082669.0        37.2
# 3      18    22             Louisiana   4645670.0        36.2
# 4       3    05              Arkansas   2968472.0        37.7
# 5      17    21              Kentucky   4411989.0        38.6
# 6       0    01               Alabama   4841164.0        38.6
# 7       2    04               Arizona   6728577.0        37.1
# 8      10    13               Georgia  10099320.0        36.2
# 9      48    54         West Virginia   1846092.0        41.9
# 10      8    11  District of Columbia    659009.0        33.8
# 11     42    47             Tennessee   6548009.0        38.5
# 12     40    45        South Carolina   4834605.0        38.8
# 13     33    37        North Carolina   9940828.0        38.3
# ...

# %%
#States with least High School degrees in 2013 
lowest_highschool_2013 = edu_2013.sort_values(["High School and above"])

lowest_highschool_2013.reset_index(inplace=True)

lowest_highschool_2013        #NOTE: WE NEED THE FILTER THE POPULATION DATA TO SHOW THE POPULATION OF 25 AND ABOVE
# Out:
#     index State                  Name  Population      None  \
# 0      50    56               Wyoming    570134.0    1169.0
# 1       1    02                Alaska    720316.0    2796.0
# 2      34    38          North Dakota    689781.0    2534.0
# 3       8    11  District of Columbia    619371.0    4818.0
# 4      45    50               Vermont    625904.0    2062.0
# 5      41    46          South Dakota    825198.0    2855.0
# 6       7    10              Delaware    908446.0    6361.0
# 7      26    30               Montana    998554.0    2733.0
# 8      39    44          Rhode Island   1051695.0   12556.0
# 9      12    16                 Idaho   1583364.0   10194.0
# 10     11    15                Hawaii   1376298.0   10126.0
# 11     29    33         New Hampshire   1319171.0    5512.0
# 12     19    23                 Maine   1328320.0    5597.0
# 13     27    31              Nebraska   1841625.0   10656.0
# 14     31    35            New Mexico   2069706.0   19031.0
# ...

# %%
#states= eco_2013["Name"].tolist()
#y_axis=eco_2013["Unemployment Rate"].tolist()
#x_axis = np.arange(len(y_axis))
#plt.bar(x_axis, y_axis, color="b", align="center")
#tick_locations = [value for value in x_axis]
#plt.xticks(tick_locations, states)
#plt.figure(figsize = (15,10))
#plt.show()

# %%
grouped_eco_2012= eco_2012.groupby(["Name"])["Poverty Rate"].mean()
grouped_eco_2012

unemployed_eco_2012= eco_2012.groupby(["Name"])["Unemployment Rate"].mean()

# %%
ax = grouped_eco_2012.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Poverty Rate in 2012',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Poverty Rate', fontsize=18)
plt.savefig('Images/2012/Poverty_Rate_2012.png')
plt.show()

# %%
ax = unemployed_eco_2012.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Unemployment Rate in 2012',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Unemployment Rate', fontsize=18)
plt.savefig('Images/2012/Unemployment_Rate_2012.png')
plt.show()

# %%
grouped_eco_2013= eco_2013.groupby(["Name"])["Poverty Rate"].mean()
ax = grouped_eco_2013.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Poverty Rate in 2013',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Poverty Rate', fontsize=18)
plt.savefig('Images/2013/Poverty_Rate_2013.png')
plt.show()

# %%
unemployed_eco_2013= eco_2013.groupby(["Name"])["Unemployment Rate"].mean()
ax = grouped_eco_2013.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Unemployment Rate in 2013',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Unemployment Rate', fontsize=18)
plt.savefig('Images/2013/Unemployment_Rate_2013.png')
plt.show()

# %%
grouped_eco_2014= eco_2014.groupby(["Name"])["Poverty Rate"].mean()
ax = grouped_eco_2014.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Poverty Rate in 2014',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Poverty Rate', fontsize=18)
plt.savefig('Images/2014/Poverty_Rate_2014.png')
plt.show()

# %%
unemployed_eco_2014= eco_2014.groupby(["Name"])["Unemployment Rate"].mean()
ax = grouped_eco_2014.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Unemployment Rate in 2014',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Unemployment Rate', fontsize=18)
plt.savefig('Images/2014/Unemployment_Rate_2014.png')
plt.show()

# %%
grouped_eco_2015= eco_2015.groupby(["Name"])["Poverty Rate"].mean()
ax = grouped_eco_2015.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Poverty Rate in 2015',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Poverty Rate', fontsize=18)
plt.savefig('Images/2015/Poverty_Rate_2015.png')
plt.show()

# %%
unemployed_eco_2015= eco_2015.groupby(["Name"])["Unemployment Rate"].mean()
ax = grouped_eco_2015.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Unemployment Rate in 2015',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Unemployment Rate', fontsize=18)
plt.savefig('Images/2015/Unemployment_Rate_2015.png')
plt.show()

# %%
grouped_eco_2016= eco_2016.groupby(["Name"])["Poverty Rate"].mean()
ax = grouped_eco_2016.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Poverty Rate in 2016',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Poverty Rate', fontsize=18)
plt.savefig('Images/2016/Poverty_Rate_2016.png')
plt.show()

# %%
unemployed_eco_2016= eco_2016.groupby(["Name"])["Unemployment Rate"].mean()
ax = grouped_eco_2016.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Unemployment Rate in 2016',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Unemployment Rate', fontsize=18)
plt.savefig('Images/2016/Unemployment_Rate_2016.png')
plt.show()

# %%
eco_2012.describe()
# Out:
#          Population  Median Age  Household Income  Per Capita Income  \
# count  5.200000e+01   52.000000         52.000000          52.000000
# mean   6.016451e+06   37.498077      52672.903846       27566.211538
# std    6.778520e+06    2.280737       9830.330482        5145.456383
# min    5.628030e+05   29.300000      19515.000000       10850.000000
# 25%    1.762430e+06   36.300000      46873.750000       24492.000000
# 50%    4.088398e+06   37.400000      51327.000000       26534.000000
# 75%    6.605125e+06   38.725000      58464.500000       29801.000000
# max    3.732507e+07   42.800000      72999.000000       45004.000000
#
#        Poverty Count  Poverty Rate  Employable Count  Unemployment Count  \
# count   5.200000e+01     52.000000      5.200000e+01        5.200000e+01
# mean    8.944411e+05     14.542325      3.036478e+06        2.842091e+05
# std     1.050314e+06      5.187570      3.394693e+06        3.501541e+05
# ...

# %%
poverty_above_mean_2012 = eco_2012.loc[eco_2012['Poverty Rate'] >= 14.5]
poverty_above_mean_2012

unemployment_above_mean_2012= eco_2012.loc[eco_2012['Unemployment Rate'] >= 8.69]

per_capita_below_mean_2012=eco_2012.loc[eco_2012["Per Capita Income"] < 27566]

# %%
poverty_grouped_eco_2012= poverty_above_mean_2012.groupby(["Name"])["Poverty Rate"].mean()
ax =poverty_grouped_eco_2012.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Poverty Rate Above Mean in 2012',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Poverty Rate', fontsize=18)
plt.savefig('Images/2012/Poverty_Rate_above_mean_2012.png')
plt.show()

# %%
unemployment_grouped_eco_2012= unemployment_above_mean_2012.groupby(["Name"])["Unemployment Rate"].mean()
ax =unemployment_grouped_eco_2012.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Unemployment Rate Above Mean in 2012',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Unemployment', fontsize=18)
plt.savefig('Images/2012/Unemployment_Rate_above_mean_2012.png')
plt.show()

# %%
per_capita_grouped_eco_2012= per_capita_below_mean_2012.groupby(["Name"])["Per Capita Income"].mean()
ax =per_capita_grouped_eco_2012.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Per Capita Income Below Mean in 2012',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Per Capita Income', fontsize=18)
plt.savefig('Images/2012/Per_Capita_income_below_mean_2012.png')
plt.show()

# %%
eco_2013.describe()
# Out:
#          Population  Median Age  Household Income  Per Capita Income  \
# count  5.200000e+01   52.000000         52.000000          52.000000
# mean   6.061915e+06   37.636538      52878.230769       27727.153846
# std    6.844265e+06    2.329271       9883.958365        5180.013197
# min    5.701340e+05   29.600000      19624.000000       11068.000000
# 25%    1.777060e+06   36.300000      46658.750000       24586.750000
# 50%    4.115027e+06   37.600000      51757.500000       26816.500000
# 75%    6.658688e+06   38.925000      58985.250000       29981.500000
# max    3.765918e+07   43.200000      73538.000000       45290.000000
#
#        Poverty Count  Poverty Rate  Employable Count  Unemployment Count  \
# count   5.200000e+01     52.000000      5.200000e+01        5.200000e+01
# mean    9.289916e+05     14.944910      3.047324e+06        2.980195e+05
# std     1.096944e+06      5.186343      3.419269e+06        3.684753e+05
# ...

# %%
poverty_above_mean_2013 = eco_2013.loc[eco_2013['Poverty Rate'] >= 14.9]
poverty_above_mean_2013

unemployment_above_mean_2013= eco_2013.loc[eco_2013['Unemployment Rate'] >= 9.07]
per_capita_below_mean_2013=eco_2013.loc[eco_2013["Per Capita Income"] < 27727]

# %%
poverty_grouped_eco_2013= poverty_above_mean_2013.groupby(["Name"])["Poverty Rate"].mean()
ax = poverty_grouped_eco_2013.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Poverty Rate Above Mean in 2013',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Poverty Rate', fontsize=18)
plt.savefig('Images/2013/Poverty_Rate_above_mean_2013.png')
plt.show()

# %%
unemployment_grouped_eco_2013= unemployment_above_mean_2013.groupby(["Name"])["Unemployment Rate"].mean()
ax =unemployment_grouped_eco_2013.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Unemployment Rate Above Mean in 2013',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Unemployment', fontsize=18)
plt.savefig('Images/2013/Unemployment_Rate_above_mean_2013.png')
plt.show()

# %%
per_capita_grouped_eco_2013= per_capita_below_mean_2013.groupby(["Name"])["Per Capita Income"].mean()
ax =per_capita_grouped_eco_2013.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Per Capita Income Below Mean in 2013',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Per Capita Income', fontsize=18)
plt.savefig('Images/2013/Per_Capita_income_below_mean_2013.png')
plt.show()

# %%
eco_2014.describe()
# Out:
#          Population  Median Age  Household Income  Per Capita Income  \
# count  5.200000e+01   52.000000         52.000000          52.000000
# mean   6.110501e+06   37.736538      53468.788462       28159.365385
# std    6.921369e+06    2.360876      10115.434499        5288.496002
# min    5.752510e+05   29.900000      19686.000000       11331.000000
# 25%    1.790277e+06   36.275000      47100.500000       24917.500000
# 50%    4.141808e+06   37.900000      52302.500000       27252.500000
# 75%    6.717749e+06   39.100000      59942.250000       30797.250000
# max    3.806692e+07   43.500000      74149.000000       46502.000000
#
#        Poverty Count  Poverty Rate  Employable Count  Unemployment Count  \
# count   5.200000e+01     52.000000      5.200000e+01        5.200000e+01
# mean    9.497418e+05     15.134475      3.062769e+06        2.836075e+05
# std     1.129752e+06      5.186665      3.450168e+06        3.523016e+05
# ...

# %%
poverty_above_mean_2014 = eco_2014.loc[eco_2014['Poverty Rate'] >= 15.1]
poverty_above_mean_2014

unemployment_above_mean_2014= eco_2014.loc[eco_2014['Unemployment Rate'] >= 8.62]
per_capita_below_mean_2014=eco_2014.loc[eco_2014["Per Capita Income"] < 28159]

# %%
poverty_grouped_eco_2014= poverty_above_mean_2014.groupby(["Name"])["Poverty Rate"].mean()
ax = poverty_grouped_eco_2014.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Poverty Rate Above Mean in 2014',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Poverty Rate', fontsize=18)
plt.savefig('Images/2014/Poverty_Rate_above_mean_2014.png')
plt.show()

# %%
unemployment_grouped_eco_2014= unemployment_above_mean_2014.groupby(["Name"])["Unemployment Rate"].mean()
ax =unemployment_grouped_eco_2014.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Unemployment Rate Above Mean in 2014',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Unemployment', fontsize=18)
plt.savefig('Images/2014/Unemployment_Rate_above_mean_2014.png')
plt.show()

# %%
per_capita_grouped_eco_2014= per_capita_below_mean_2014.groupby(["Name"])["Per Capita Income"].mean()
ax =per_capita_grouped_eco_2014.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Per Capita Income Below Mean in 2014',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Per Capita Income', fontsize=18)
plt.savefig('Images/2014/Per_Capita_income_below_mean_2014.png')
plt.show()

# %%
eco_2015.describe()
# Out:
#          Population  Median Age  Household Income  Per Capita Income  \
# count  5.200000e+01   52.000000         52.000000          52.000000
# mean   6.155733e+06   37.859615      53957.519231       28531.884615
# std    6.992999e+06    2.395114      10303.108321        5396.543246
# min    5.796790e+05   30.100000      19350.000000       11394.000000
# 25%    1.792702e+06   36.450000      47422.500000       25316.250000
# 50%    4.168293e+06   38.000000      52601.000000       27669.500000
# 75%    6.775556e+06   39.225000      60653.500000       31279.000000
# max    3.842146e+07   43.800000      74551.000000       47675.000000
#
#        Poverty Count  Poverty Rate  Employable Count  Unemployment Count  \
# count   5.200000e+01     52.000000      5.200000e+01        5.200000e+01
# mean    9.493300e+05     15.028206      3.080710e+06        2.574196e+05
# std     1.131181e+06      5.235769      3.483077e+06        3.200497e+05
# ...

# %%
poverty_above_mean_2015 = eco_2015.loc[eco_2015['Poverty Rate'] >= 15.1]
poverty_above_mean_2015

unemployment_above_mean_2015= eco_2015.loc[eco_2015['Unemployment Rate'] >= 7.82]
per_capita_below_mean_2015=eco_2015.loc[eco_2015["Per Capita Income"] < 28531]

# %%
poverty_grouped_eco_2015= poverty_above_mean_2015.groupby(["Name"])["Poverty Rate"].mean()
ax = poverty_grouped_eco_2015.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Poverty Rate Above Mean in 2015',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Poverty Rate', fontsize=18)
plt.savefig('Images/2015/Poverty_Rate_above_mean_2015.png')
plt.show()

# %%
unemployment_grouped_eco_2015= unemployment_above_mean_2015.groupby(["Name"])["Unemployment Rate"].mean()
ax =unemployment_grouped_eco_2015.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Unemployment Rate Above Mean in 2015',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Unemployment', fontsize=18)
plt.savefig('Images/2015/Unemployment_Rate_above_mean_2015.png')
plt.show()

# %%
per_capita_grouped_eco_2015= per_capita_below_mean_2015.groupby(["Name"])["Per Capita Income"].mean()
ax =per_capita_grouped_eco_2015.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Per Capita Income Below Mean in 2015',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Per Capita Income', fontsize=18)
plt.savefig('Images/2015/Per_Capita_income_below_mean_2015.png')
plt.show()

# %%
eco_2016.describe()
# Out:
#          Population  Median Age  Household Income  Per Capita Income  \
# count  5.200000e+01   52.000000         52.000000          52.000000
# mean   6.193991e+06   38.007692      55330.576923       29367.096154
# std    7.049612e+06    2.410178      10594.991553        5522.679835
# min    5.830290e+05   30.300000      19606.000000       11688.000000
# 25%    1.793440e+06   36.625000      48770.000000       26092.500000
# 50%    4.197128e+06   38.100000      53977.500000       28475.500000
# 75%    6.824894e+06   39.400000      62518.500000       32177.750000
# max    3.865421e+07   44.000000      76067.000000       48781.000000
#
#        Poverty Count  Poverty Rate  Employable Count  Unemployment Count  \
# count   5.200000e+01     52.000000      5.200000e+01        5.200000e+01
# mean    9.328712e+05     14.726984      3.097867e+06        2.313972e+05
# std     1.109642e+06      5.193001      3.510431e+06        2.864133e+05
# ...

# %%
poverty_above_mean_2016 = eco_2016.loc[eco_2016['Poverty Rate'] >= 14.7]
poverty_above_mean_2016

unemployment_above_mean_2016= eco_2016.loc[eco_2016['Unemployment Rate'] >= 7.06]
per_capita_below_mean_2016=eco_2016.loc[eco_2015["Per Capita Income"] < 29367]

# %%
poverty_grouped_eco_2016= poverty_above_mean_2016.groupby(["Name"])["Poverty Rate"].mean()
ax = poverty_grouped_eco_2016.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Poverty Rate Above Mean in 2016',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Poverty Rate', fontsize=18)
plt.savefig('Images/2016/Poverty_Rate_above_mean_2016.png')
plt.show()

# %%
unemployment_grouped_eco_2016= unemployment_above_mean_2016.groupby(["Name"])["Unemployment Rate"].mean()
ax =unemployment_grouped_eco_2016.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Unemployment Rate Above Mean in 2016',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Unemployment', fontsize=18)
plt.savefig('Images/2016/Unemployment_Rate_above_mean_2016.png')
plt.show()

# %%
per_capita_grouped_eco_2016= per_capita_below_mean_2016.groupby(["Name"])["Per Capita Income"].mean()
ax =per_capita_grouped_eco_2016.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Per Capita Income Below Mean in 2016',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Per Capita Income', fontsize=18)
plt.savefig('Images/2016/Per_Capita_income_below_mean_2016.png')
plt.show()

# %%
poverty_below_mean_2012 = eco_2012.loc[eco_2012['Poverty Rate'] <= 14.5]
poverty_below_mean_2012

unemployment_below_mean_2012= eco_2012.loc[eco_2012['Unemployment Rate'] <= 8.69]
per_capita_above_mean_2012=eco_2012.loc[eco_2012["Per Capita Income"] > 27566]

poverty_below_grouped_eco_2012= poverty_below_mean_2012.groupby(["Name"])["Poverty Rate"].mean()
ax =poverty_below_grouped_eco_2012.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Poverty Rate Below Mean in 2012',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Poverty Rate', fontsize=18)
plt.savefig('Images/2012/Poverty_Rate_below_mean_2012.png')
plt.show()

# %%
unemployment_below_grouped_eco_2012= unemployment_below_mean_2012.groupby(["Name"])["Unemployment Rate"].mean()
ax =unemployment_below_grouped_eco_2012.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Unemployment Rate Below Mean in 2012',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Unemployment', fontsize=18)
plt.savefig('Images/2012/Unemployment_Rate_below_mean_2012.png')
plt.show()

# %%
per_capita_above_grouped_eco_2012= per_capita_above_mean_2012.groupby(["Name"])["Per Capita Income"].mean()
ax =per_capita_above_grouped_eco_2012.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Per Capita Income Above Mean in 2012',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Per Capita Income', fontsize=18)
plt.savefig('Images/2012/Per_Capita_income_above_mean_2012.png')
plt.show()

# %%
poverty_below_mean_2013 = eco_2013.loc[eco_2013['Poverty Rate'] <= 14.9]
poverty_below_mean_2013

unemployment_below_mean_2013= eco_2013.loc[eco_2013['Unemployment Rate'] <= 9.07]
per_capita_above_mean_2013=eco_2013.loc[eco_2013["Per Capita Income"] > 27727]

poverty_below_grouped_eco_2012= poverty_below_mean_2012.groupby(["Name"])["Poverty Rate"].mean()
ax =poverty_below_grouped_eco_2012.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Poverty Rate Below Mean in 2013',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Poverty Rate', fontsize=18)
plt.savefig('Images/2013/Poverty_Rate_below_mean_2013.png')
plt.show()

# %%
unemployment_below_grouped_eco_2013= unemployment_below_mean_2013.groupby(["Name"])["Unemployment Rate"].mean()
ax =unemployment_below_grouped_eco_2013.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Unemployment Rate Below Mean in 2013',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Unemployment', fontsize=18)
plt.savefig('Images/2013/Unemployment_Rate_below_mean_2013.png')
plt.show()

# %%
per_capita_above_grouped_eco_2013= per_capita_above_mean_2013.groupby(["Name"])["Per Capita Income"].mean()
ax =per_capita_above_grouped_eco_2013.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Per Capita Income Above Mean in 2013',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Per Capita Income', fontsize=18)
plt.savefig('Images/2013/Per_Capita_income_above_mean_2013.png')
plt.show()

# %%
poverty_below_mean_2014 = eco_2014.loc[eco_2012['Poverty Rate'] <= 15.1]
poverty_below_mean_2014

unemployment_below_mean_2014= eco_2014.loc[eco_2014['Unemployment Rate'] <= 8.62]
per_capita_above_mean_2014=eco_2014.loc[eco_2014["Per Capita Income"] > 28159]

poverty_below_grouped_eco_2014= poverty_below_mean_2014.groupby(["Name"])["Poverty Rate"].mean()
ax =poverty_below_grouped_eco_2014.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Poverty Rate Below Mean in 2014',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Poverty Rate', fontsize=18)
plt.savefig('Images/2014/Poverty_Rate_below_mean_2014.png')
plt.show()

# %%
unemployment_below_grouped_eco_2014= unemployment_below_mean_2014.groupby(["Name"])["Unemployment Rate"].mean()
ax =unemployment_below_grouped_eco_2014.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Unemployment Rate Below Mean in 2014',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Unemployment', fontsize=18)
plt.savefig('Images/2014/Unemployment_Rate_below_mean_2014.png')
plt.show()

# %%
per_capita_above_grouped_eco_2014= per_capita_above_mean_2014.groupby(["Name"])["Per Capita Income"].mean()
ax =per_capita_above_grouped_eco_2014.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Per Capita Income Above Mean in 2014',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Per Capita Income', fontsize=18)
plt.savefig('Images/2014/Per_Capita_income_above_mean_2014.png')
plt.show()

# %%
poverty_below_mean_2015 = eco_2015.loc[eco_2015['Poverty Rate'] <= 15.1]
poverty_below_mean_2015

unemployment_below_mean_2015= eco_2015.loc[eco_2015['Unemployment Rate'] <= 7.82]
per_capita_above_mean_2015=eco_2015.loc[eco_2015["Per Capita Income"] > 28531]

poverty_below_grouped_eco_2015= poverty_below_mean_2015.groupby(["Name"])["Poverty Rate"].mean()
ax =poverty_below_grouped_eco_2015.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Poverty Rate Below Mean in 2015',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Poverty Rate', fontsize=18)
plt.savefig('Images/2015/Poverty_Rate_below_mean_2015.png')
plt.show()

# %%
unemployment_below_grouped_eco_2015= unemployment_below_mean_2015.groupby(["Name"])["Unemployment Rate"].mean()
ax =unemployment_below_grouped_eco_2015.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Unemployment Rate Below Mean in 2015',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Unemployment', fontsize=18)
plt.savefig('Images/2015/Unemployment_Rate_below_mean_2015.png')
plt.show()

# %%
per_capita_above_grouped_eco_2015= per_capita_above_mean_2015.groupby(["Name"])["Per Capita Income"].mean()
ax =per_capita_above_grouped_eco_2015.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Per Capita Income Above Mean in 2015',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Per Capita Income', fontsize=18)
plt.savefig('Images/2015/Per_Capita_income_above_mean_2015.png')
plt.show()

# %%
poverty_below_mean_2016 = eco_2016.loc[eco_2016['Poverty Rate'] <= 14.7]
poverty_below_mean_2016

unemployment_below_mean_2016= eco_2016.loc[eco_2016['Unemployment Rate'] <= 7.06]
per_capita_above_mean_2016=eco_2016.loc[eco_2016["Per Capita Income"] > 29367]

poverty_below_grouped_eco_2016= poverty_below_mean_2016.groupby(["Name"])["Poverty Rate"].mean()
ax =poverty_below_grouped_eco_2016.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Poverty Rate Below Mean in 2016',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Poverty Rate', fontsize=18)
plt.savefig('Images/2016/Poverty_Rate_below_mean_2016.png')
plt.show()

# %%
unemployment_below_grouped_eco_2016= unemployment_below_mean_2016.groupby(["Name"])["Unemployment Rate"].mean()
ax =unemployment_below_grouped_eco_2016.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Unemployment Rate Below Mean in 2016',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Unemployment', fontsize=18)
plt.savefig('Images/2016/Unemployment_Rate_below_mean_2016.png')
plt.show()

# %%
per_capita_above_grouped_eco_2016= per_capita_above_mean_2016.groupby(["Name"])["Per Capita Income"].mean()
ax =per_capita_above_grouped_eco_2016.plot(kind="bar",figsize=(20,10), fontsize=14, legend=False)
plt.legend(loc='best', fontsize=13)
plt.title(f'Per Capita Income Above Mean in 2016',fontsize=18)
ax.set_xlabel('State', fontsize=18)
ax.set_ylabel('Per Capita Income', fontsize=18)
plt.savefig('Images/2016/Per_Capita_income_above_mean_2016.png')
plt.show()
