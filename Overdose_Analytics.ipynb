# %%
#import Dependencies
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
#read in the file
overdose_df= pd.read_csv("VSRR_Provisional_Drug_Overdose_Death_Counts.csv")

# %%
#overview of data
overdose_df.head()
# Out:
#   State State Name  Year     Month         Indicator  Data Value  \
# 0    AK     Alaska  2015   January  Number of Deaths      4034.0
# 1    AK     Alaska  2015  February  Number of Deaths      4084.0
# 2    AK     Alaska  2015     March  Number of Deaths      4101.0
# 3    AK     Alaska  2015     April  Number of Deaths      4133.0
# 4    AK     Alaska  2015       May  Number of Deaths      4196.0
#
#    Predicted Value  Percent Complete  Percent Pending Investigation Footnote
# 0              NaN               100                            0.0      NaN
# 1              NaN               100                            0.0      NaN
# 2              NaN               100                            0.0      NaN
# 3              NaN               100                            0.0      NaN
# 4              NaN               100                            0.0      NaN

# %%
#statistical summary of data
overdose_df.describe
# Out:
# <bound method NDFrame.describe of      State     State Name  Year      Month  \
# 0       AK         Alaska  2015    January
# 1       AK         Alaska  2015   February
# 2       AK         Alaska  2015      March
# 3       AK         Alaska  2015      April
# 4       AK         Alaska  2015        May
# 5       AK         Alaska  2015       June
# 6       AK         Alaska  2015       July
# 7       AK         Alaska  2015     August
# 8       AK         Alaska  2015  September
# 9       AK         Alaska  2015    October
# 10      AK         Alaska  2015   November
# 11      AK         Alaska  2015   December
# 12      AK         Alaska  2016    January
# 13      AK         Alaska  2016   February
# 14      AK         Alaska  2016      March
# 15      AK         Alaska  2016      April
# 16      AK         Alaska  2016        May
# 17      AK         Alaska  2016       June
# 18      AK         Alaska  2016       July
# 19      AK         Alaska  2016     August
# ...

# %%
#overview of columns 
overdose_df.columns
# Out:
# Index(['State', 'State Name', 'Year', 'Month', 'Indicator', 'Data Value',
#        'Predicted Value', 'Percent Complete', 'Percent Pending Investigation',
#        'Footnote'],
#       dtype='object')

# %%
#create a new data frame with usable columns 
new_overdose_df = overdose_df[['State','Year','Month','Indicator','Data Value']]
new_overdose_df.head()
# Out:
#   State  Year     Month         Indicator  Data Value
# 0    AK  2015   January  Number of Deaths      4034.0
# 1    AK  2015  February  Number of Deaths      4084.0
# 2    AK  2015     March  Number of Deaths      4101.0
# 3    AK  2015     April  Number of Deaths      4133.0
# 4    AK  2015       May  Number of Deaths      4196.0

# %%
#check the contents of the new_overdose_df 
new_overdose_df.describe
new_overdose_df.columns
# Out:
# Index(['State', 'Year', 'Month', 'Indicator', 'Data Value'], dtype='object')

# %%
#check the number of unique indicator /deaths by drug type
new_overdose_df['Indicator'].unique
# Out:
# <bound method Series.unique of 0                                 Number of Deaths
# 1                                 Number of Deaths
# 2                                 Number of Deaths
# 3                                 Number of Deaths
# 4                                 Number of Deaths
# 5                                 Number of Deaths
# 6                                 Number of Deaths
# 7                                 Number of Deaths
# 8                                 Number of Deaths
# 9                                 Number of Deaths
# 10                                Number of Deaths
# 11                                Number of Deaths
# 12                                Number of Deaths
# 13                                Number of Deaths
# 14                                Number of Deaths
# 15                                Number of Deaths
# 16                                Number of Deaths
# 17                                Number of Deaths
# ...

# %%
State_df = new_overdose_df.groupby('State')
State_df

# %%
Deaths_Per_State = new_overdose_df.groupby('State')['Indicator'].value_counts()
Deaths_Per_State 
Deaths_per_State.unstack(level=0)

# %%
number_of_Deaths = new_overdose_df['Indicator'].iloc[2:36]
number_of_Deaths

# %%
for k,v in replace_vals.items():
    .new_overdose_df.iloc[(new_overdose_df[2:36] == k[Deaths]) 
df
